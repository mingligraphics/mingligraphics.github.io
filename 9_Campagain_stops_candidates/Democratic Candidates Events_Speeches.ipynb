# %% [markdown]
# ## 1. Get the name, personal id and kick-off date of campagin from C-span

# %%
import requests
import pandas as pd
import re
import calendar


from bs4 import BeautifulSoup

# %%
url = "https://www.c-span.org/series/?roadToTheWhiteHouse#candidates-tab"
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
rows = []
candidates = doc.find_all(class_="D")
for candidate in candidates:
    row ={}
    try:
        row['name'] = candidate.find(class_="candidate D").text
    except:
        pass
    try:
        row['kickoff_date'] = candidate.find(class_="datetime").text
    except:
        pass
    try:
        row['person_id'] = candidate.find(class_="search-candidate")['href']
    except:
        pass
    rows.append(row)

# %%
df = pd.DataFrame(rows)
df = df.dropna(subset=['name'])
df = df[['name', 'kickoff_date', 'person_id']]

# %%
df['kickoff_date'] = df['kickoff_date'].astype(str)

# %%
df['kickoff_date'] = df['kickoff_date'].str.extract(r":(.*)")

# %%
df['person_id'] = df['person_id'].str.extract(r"=(\d+)$")
df
# Out:
#                      name        kickoff_date person_id
# 0          Michael Bennet         May 2, 2019   1031622
# 2           Joe Biden Jr.      April 25, 2019        34
# 4             Cory Booker    February 1, 2019     84679
# 6           Steve Bullock        May 14, 2019   9276486
# 8          Pete Buttigieg      April 14, 2019    106618
# 10          Julian Castro    January 12, 2019   9278200
# 12        John K. Delaney     August 10, 2017     67856
# 14          Tulsi Gabbard    January 11, 2019   1025291
# 16  Kirsten E. Gillibrand    January 14, 2019   1022862
# 18       Kamala D. Harris    January 21, 2019   1018696
# 20   John W. Hickenlooper       March 4, 2019   1016627
# 22             Jay Inslee       March 1, 2019     26139
# 24          Amy Klobuchar   February 10, 2019     83701
# 26        Seth W. Moulton      April 22, 2019     78453
# 28          Beto O'Rourke      March 14, 2019     79697
# 30               Tim Ryan       April 4, 2019   1003608
# 32         Bernie Sanders   February 19, 2019       994
# 34         Joe Sestak Jr.       June 23, 2019       NaN
# 36          Eric Swalwell       April 8, 2019     79729
# 38       Elizabeth Warren   December 31, 2018   1023023
# 40    Marianne Williamson    January 28, 2019     49808
# 42            Andrew Yang    November 6, 2017     96807
# 44     Bill de Blasio Jr.        May 16, 2019   9263693
# 46          Maggie Hassan                 NaN     67481
# 48           Jason Kander                 NaN    104991

# %%
df['kickoff_date'] = pd.to_datetime(df['kickoff_date'])

# %%
df
# Out:
#                      name kickoff_date person_id
# 0          Michael Bennet   2019-05-02   1031622
# 2           Joe Biden Jr.   2019-04-25        34
# 4             Cory Booker   2019-02-01     84679
# 6           Steve Bullock   2019-05-14   9276486
# 8          Pete Buttigieg   2019-04-14    106618
# 10          Julian Castro   2019-01-12   9278200
# 12        John K. Delaney   2017-08-10     67856
# 14          Tulsi Gabbard   2019-01-11   1025291
# 16  Kirsten E. Gillibrand   2019-01-14   1022862
# 18       Kamala D. Harris   2019-01-21   1018696
# 20   John W. Hickenlooper   2019-03-04   1016627
# 22             Jay Inslee   2019-03-01     26139
# 24          Amy Klobuchar   2019-02-10     83701
# 26        Seth W. Moulton   2019-04-22     78453
# 28          Beto O'Rourke   2019-03-14     79697
# 30               Tim Ryan   2019-04-04   1003608
# 32         Bernie Sanders   2019-02-19       994
# 34         Joe Sestak Jr.   2019-06-23       NaN
# 36          Eric Swalwell   2019-04-08     79729
# 38       Elizabeth Warren   2018-12-31   1023023
# 40    Marianne Williamson   2019-01-28     49808
# 42            Andrew Yang   2017-11-06     96807
# 44     Bill de Blasio Jr.   2019-05-16   9263693
# 46          Maggie Hassan          NaT     67481
# 48           Jason Kander          NaT    104991

# %%
df.to_csv("candidates_info.csv", index=False)

# %% [markdown]
# ## 2. Get speech and event stops of Bernie Sanders
# ### 2.1. Scrape Bernie Sanders' speech coverage at C-span

# %%
url = "https://www.c-span.org/search/?empty-date=1&sdate=&edate=&searchtype=Videos&sort=Most+Recent+Airing&text=0&&personid%5B%5D=994&formatid%5B%5D=55&show100="
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
rows = []
videos = doc.find(class_="video-results").find_all('li')
for video in videos:
    row={}
    row['date'] = video.find(class_="time").text
    row['place'] = video.find('h3').text
    row['summary'] = video.find(class_="abstract").text
    row['url'] = video.find('a')['href']
    rows.append(row)

# %%
df_sanders = pd.DataFrame(rows)
df_sanders.head()
# Out:
#             date                                              place  \
# 0  June 23, 2019  Senator Bernie Sanders Town Hall at Clinton Co...
# 1  June 22, 2019  South Carolina Democratic Party Convention: Se...
# 2  June 12, 2019  Senator Bernie Sanders Remarks on Democratic S...
# 3   June 9, 2019           Iowa Democratic Party Hall of Fame Forum
# 4   May 25, 2019  Senator Bernie Sanders Rally in Montpelier, Ve...
#
#                                              summary  \
# 0  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 3  The Iowa Democratic Party held its Hall of Fam...
# 4  Senator Bernie Sanders (I-VT), a 2020 Democrat...
#
#                                                  url
# 0  //www.c-span.org/video/?461881-1/senator-berni...
# 1  //www.c-span.org/video/?461983-8/south-carolin...
# 2  //www.c-span.org/video/?461581-1/senator-berni...
# 3  //www.c-span.org/video/?461356-1/white-house-h...
# 4  //www.c-span.org/video/?460966-1/senator-berni...

# %%
df_sanders['date'] = pd.to_datetime(df_sanders['date'])
df_sanders['summary'] = df_sanders.summary.astype(str)
df_sanders = df_sanders[df_sanders.summary.str.contains('Sanders')]
df_sanders
# Out:
#          date                                              place  \
# 0  2019-06-23  Senator Bernie Sanders Town Hall at Clinton Co...
# 1  2019-06-22  South Carolina Democratic Party Convention: Se...
# 2  2019-06-12  Senator Bernie Sanders Remarks on Democratic S...
# 4  2019-05-25  Senator Bernie Sanders Rally in Montpelier, Ve...
# 5  2019-05-04                     Senator Bernie Sanders in Iowa
# 6  2019-04-12  Senator Sanders Campaign Rally in Madison, Wis...
# 7  2019-03-10  Senator Bernie Sanders Campaign Event in Conco...
# 8  2019-03-02  Senator Bernie Sanders Presidential Campaign A...
# 9  2019-02-19  Senator Bernie Sanders Presidential Campaign A...
# 11 2018-11-27                              Where We Go From Here
# 12 2018-10-27  Senator Bernie Sanders at Campaign Rally in Ca...
# 13 2018-10-09  Senator Bernie Sanders Remarks at Johns Hopkin...
# 14 2018-05-31                              Where We Go from Here
# 15 2017-10-14                          Weekly Democratic Address
# 16 2017-08-31       Bernie Sanders Guide to Political Revolution
# 17 2017-05-30         Brooklyn College 2017 Commencement Address
# 18 2017-02-27  U.S.-Israel Relations and Middle East, Senator...
# 19 2016-11-19                                     Our Revolution
# 21 2016-11-16         Senator Bernie Sanders on Trump Presidency
# 22 2016-11-03  Presidential Candidate Hillary Clinton Rally i...
# 23 2016-09-28  Presidential Candidate Hillary Clinton Rally i...
# 24 2016-07-26               Florida Delegation Breakfast, Part 2
# 25 2016-07-26                     Wisconsin Delegation Breakfast
# 26 2016-07-12  Senator Bernie Sanders Campaign Event with Hil...
# 27 2016-06-09  Presidential Candidate Bernie Sanders Rally in...
# 28 2016-06-08  Presidential Candidate Bernie Sanders Primary ...
# 29 2016-03-13                Ohio Democratic Party Legacy Dinner
# 30 2016-06-04  Senator Bernie Sanders Town Hall Meeting in Lo...
# 31 2016-05-26  Senator Bernie Sanders Campaign Rally in Ventu...
# 32 2016-05-17  Senator Bernie Sanders Campaign Rally in Carso...
# ..        ...                                                ...
# 63 2016-02-01         Senator Bernie Sanders Caucus Night Speech
# 64 2016-01-31  Senator Bernie Sanders Campaign Rally in Water...
# 65 2016-01-27  Senator Bernie Sanders Campaign Event in Mason...
# 66 2016-01-26  Senator Bernie Sanders Meeting with Iowa Steel...
# 67 2016-01-21  Senator Bernie Sanders Town Hall Meeting in Wo...
# 68 2016-01-06  Senator Bernie Sanders at First in the West Ca...
# 69 2015-12-28   Bernie Sanders Campaign Rally in North Las Vegas
# 70 2011-05-03                                         The Speech
# 71 2015-11-29  Senator Bernie Sanders Remarks at the Jefferso...
# 72 2015-11-19  Senator Sanders on Democratic Socialism and De...
# 73 2015-11-16  Senator Bernie Sanders Campaign Rally in Cleve...
# 74 2015-10-24  Presidential Candidates at the Iowa Jefferson-...
# 75 2015-10-12     Senator Bernie Sanders at No Labels Convention
# 76 2015-10-07  Senator Bernie Sanders at Congressional Hispan...
# 77 2015-09-20  Senator Bernie Sanders Town Hall Meeting in Ne...
# 78 2015-09-19  New Hampshire Democratic Party Convention, Sen...
# 79 2015-09-14       Senator Bernie Sanders at Liberty University
# 80 2015-08-28  Senator Bernie Sanders at Democratic National ...
# 81 2015-08-28  Democratic National Committee Summer Meeting, ...
# 82 2015-08-21  Senator Bernie Sanders Campaign Rally in South...
# 83 2015-08-15      Senator Bernie Sanders at the Iowa State Fair
# 84 2015-07-31  Senator Bernie Sanders Remarks at National Urb...
# 86 2015-06-20    Presidential Candidate Bernie Sanders Town Hall
# 87 2015-05-26  Senator Bernie Sanders Presidential Campaign A...
# 88 2015-02-09  Senator Bernie Sanders on Middle Class Economi...
# 89 2014-09-01          Senator Bernie Sanders at Labor Day Event
# 90 2014-04-12           Senator Bernie Sanders Town Hall Meeting
# 91 2010-08-29           Senator Bernie Sanders Town Hall Meeting
# 93 2003-05-21               Reflections on Careers in Government
# 94 1997-07-13                              Outsider in the House
#
#                                               summary  \
# 0   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 4   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 5   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 6   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 7   Senator Bernie Sanders (I-VT) hosted a rally i...
# 8   Senator Bernie Sanders (I-VT) formally announc...
# 9   Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 11  Senator Bernie Sanders (I-VT) laid out his pla...
# 12  Senator Bernie Sanders (I-VT) spoke at a “Get ...
# 13  Senator Bernie Sanders (I-VT) delivered remark...
# 14  Senator Bernie Sanders (I-VT) discussed his fo...
# 15  Senator Bernie Sanders (I-VT) delivered the De...
# 16  Senator Bernie Sanders (I-VT) talked about his...
# 17  Senator Bernie Sanders (I-VT) delivered a comm...
# 18  Senator Bernie Sanders (I-VT) gave the closing...
# 19  Senator Bernie Sanders talked about his book O...
# 21  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 22  Democratic presidential nominee Hillary Clinto...
# 23  Democratic presidential nominee Hillary Clinto...
# 24  Senator Bernie Sanders (I-VT) made a surprise ...
# 25  Senators Bernie Sanders (I-VT), Tammy Baldwin ...
# 26  Senator Bernie Sanders (I-VT) campaigned with ...
# 27  Senator Bernie Sanders (I-VT), a candidate for...
# 28  Senator Bernie Sanders (I-VT), a candidate for...
# 29  Democratic presidential candidates Hillary Cli...
# 30  Senator Bernie Sanders (I-VT), a candidate for...
# 31  Senator Bernie Sanders (I-VT), a candidate for...
# 32  Democratic presidential candidate Senator Bern...
# ..                                                ...
# 63  Senator Bernie Sanders (I-VT), a candidate for...
# 64  Senator Bernie Sanders (I-VT), who was seeking...
# 65  Senator Bernie Sanders (I-VT) spoke at a campa...
# 66  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 67  Senator Bernie Sanders (I-VT) held a town hall...
# 68  Senator Bernie Sanders (I-VT), a candidate for...
# 69  Democratic Presidential Candidate Bernie Sande...
# 70  Senator Bernie Sanders (I-VT) talked about his...
# 71  Senator Bernie Sanders (I-Vermont), a candidat...
# 72  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 73  Senator Bernie Sanders (I-VT), a 2016 presiden...
# 74  Candidates for the 2016 Democratic presidentia...
# 75  Senator Bernie Sanders (I-VT), a candidate for...
# 76  Senator Bernie Sanders (I-VT), a candidate for...
# 77  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 78  Senator Bernie Sanders, a 2016 Democratic pres...
# 79  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 80  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 81  Former Governor Martin O’Malley (D-MD), Senato...
# 82  Senator Bernie Sanders (I-VT), a candidate for...
# 83  Senator Bernie Sanders (I-VT), a candidate for...
# 84  Senator Bernie Sanders (I-VT), a 2016 Democrat...
# 86  Senator Bernie Sanders (I-VT), a candidate for...
# 87  Senator Bernie Sanders (I-VT) formally announc...
# 88  Senate Budget Committee Ranking Member Bernie ...
# 89  Senator Bernie Sanders (I-VT) spoke at the New...
# 90  Senator Bernie Sanders held a town hall meetin...
# 91  Senator Bernie Sanders (I-VT) held a town hall...
# 93  As part of a C-SPAN and Comcast project to enc...
# 94  Rep. Sanders talked about his book, Outsider i...
#
#                                                   url
# 0   //www.c-span.org/video/?461881-1/senator-berni...
# 1   //www.c-span.org/video/?461983-8/south-carolin...
# 2   //www.c-span.org/video/?461581-1/senator-berni...
# 4   //www.c-span.org/video/?460966-1/senator-berni...
# 5   //www.c-span.org/video/?460388-1/senator-berni...
# 6   //www.c-span.org/video/?459755-1/senator-berni...
# 7   //www.c-span.org/video/?458676-1/senator-berni...
# 8   //www.c-span.org/video/?458403-1/senator-berni...
# 9   //www.c-span.org/video/?458032-1/senator-berni...
# 11  //www.c-span.org/video/?454807-1/senator-berni...
# 12  //www.c-span.org/video/?453673-1/senator-berni...
# 13  //www.c-span.org/video/?452728-1/senator-berni...
# 14        //www.c-span.org/video/?445714-1/where-here
# 15  //www.c-span.org/video/?435788-2/weekly-democr...
# 16  //www.c-span.org/video/?433116-2/bernie-sander...
# 17  //www.c-span.org/video/?427996-1/brooklyn-coll...
# 18  //www.c-span.org/video/?424533-4/us-israel-rel...
# 19  //www.c-span.org/video/?417267-11/senator-bern...
# 21  //www.c-span.org/video/?418660-1/senator-berni...
# 22  //www.c-span.org/video/?417925-1/hillary-clint...
# 23  //www.c-span.org/video/?415989-1/hillary-clint...
# 24  //www.c-span.org/video/?413225-2/florida-deleg...
# 25  //www.c-span.org/video/?413204-1/senator-berni...
# 26  //www.c-span.org/video/?412571-1/bernie-sander...
# 27  //www.c-span.org/video/?410852-1/bernie-sander...
# 28  //www.c-span.org/video/?410777-1/bernie-sander...
# 29  //www.c-span.org/video/?406468-1/ohio-democrat...
# 30  //www.c-span.org/video/?410608-1/bernie-sander...
# 31  //www.c-span.org/video/?410151-1/bernie-sander...
# 32  //www.c-span.org/video/?409687-1/bernie-sander...
# ..                                                ...
# 63  //www.c-span.org/video/?404038-1/bernie-sander...
# 64  //www.c-span.org/video/?403937-1/bernie-sander...
# 65  //www.c-span.org/video/?403745-1/bernie-sander...
# 66  //www.c-span.org/video/?403687-1/bernie-sander...
# 67  //www.c-span.org/video/?403507-1/bernie-sander...
# 68  //www.c-span.org/video/?402721-3/senator-berni...
# 69  //www.c-span.org/video/?402611-1/bernie-sander...
# 70        //www.c-span.org/video/?300123-1/the-speech
# 71  //www.c-span.org/video/?401245-2/bernie-sander...
# 72  //www.c-span.org/video/?400961-1/senator-berni...
# 73  //www.c-span.org/video/?400753-1/senator-berni...
# 74  //www.c-span.org/video/?328787-1/presidential-...
# 75  //www.c-span.org/video/?328623-8/senator-berni...
# 76  //www.c-span.org/video/?328620-2/senator-berni...
# 77  //www.c-span.org/video/?328220-1/senator-berni...
# 78  //www.c-span.org/video/?328108-3/hampshire-dem...
# 79  //www.c-span.org/video/?328079-1/senator-berni...
# 80  //www.c-span.org/video/?327791-6/bernie-sander...
# 81  //www.c-span.org/video/?327791-2/martin-omalle...
# 82  //www.c-span.org/video/?327669-1/senator-berni...
# 83  //www.c-span.org/video/?327525-4/senator-berni...
# 84  //www.c-span.org/video/?327429-104/senator-ber...
# 86  //www.c-span.org/video/?326661-1/senator-berni...
# 87  //www.c-span.org/video/?326214-1/senator-berni...
# 88  //www.c-span.org/video/?324250-1/senator-berni...
# 89  //www.c-span.org/video/?321196-1/senator-berni...
# 90  //www.c-span.org/video/?318863-1/town-hall-mee...
# 91  //www.c-span.org/video/?295237-1/senator-berni...
# 93  //www.c-span.org/video/?176549-1/reflections-c...
# 94     //www.c-span.org/video/?87964-1/outsider-house
#
# [90 rows x 4 columns]

# %%
sanders_kickoff = df[df.name == "Bernie Sanders"]['kickoff_date']
sanders_kickoff
# Out:
# 32   2019-02-19
# Name: kickoff_date, dtype: datetime64[ns]

# %%
df_sanders = df_sanders[df_sanders['date'] > '2019-02-18']

# %%
df_sanders['url'] = df_sanders['url'].str.replace("//www.c-span.org/video", "")
df_sanders['place'] = df_sanders['place'].str.replace("Senator Bernie Sanders", "")
df_sanders
# Out:
# /Users/leiao/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/leiao/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         date                                              place  \
# 0 2019-06-23                       Town Hall at Clinton College
# 1 2019-06-22       South Carolina Democratic Party Convention:
# 2 2019-06-12                    Remarks on Democratic Socialism
# 4 2019-05-25                       Rally in Montpelier, Vermont
# 5 2019-05-04                                            in Iowa
# 6 2019-04-12  Senator Sanders Campaign Rally in Madison, Wis...
# 7 2019-03-10           Campaign Event in Concord, New Hampshire
# 8 2019-03-02                 Presidential Campaign Announcement
# 9 2019-02-19                 Presidential Campaign Announcement
#
#                                              summary  \
# 0  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 4  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 5  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 6  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 7  Senator Bernie Sanders (I-VT) hosted a rally i...
# 8  Senator Bernie Sanders (I-VT) formally announc...
# 9  Senator Bernie Sanders (I-VT), a 2016 Democrat...
#
#                                                  url
# 0  /?461881-1/senator-bernie-sanders-town-hall-cl...
# 1  /?461983-8/south-carolina-democratic-party-con...
# 2  /?461581-1/senator-bernie-sanders-delivers-rem...
# 4  /?460966-1/senator-bernie-sanders-rally-montpe...
# 5  /?460388-1/senator-bernie-sanders-campaigns-am...
# 6  /?459755-1/senator-bernie-sanders-campaigns-ma...
# 7  /?458676-1/senator-bernie-sanders-campaigns-ha...
# 8  /?458403-1/senator-bernie-sanders-launches-pre...
# 9  /?458032-1/senator-bernie-sanders-announces-20...

# %%
df_sanders.to_csv("sanders_info.csv", index = False)

# %% [markdown]
# ### 2.2. Scrape closed captioning transcripts for each speech of Bernie Sanders after his campagin started

# %%
def scrape_page(row):
    url_sanders = f"https://www.c-span.org/video{row['url']}"
    
    from selenium import webdriver
    driver = webdriver.Chrome()
    driver.get(url_sanders)
    
    buttons = driver.find_elements_by_class_name("link-show-full-text")
    for button in buttons:
        button.click()
    
    page = {}
    page['speech'] = '\n'.join([transcript.text.lower() for transcript in driver.find_elements_by_class_name("short_transcript")])
    
    return pd.Series(page)

# %%
scrape_page(df_sanders.loc[2])
# Out:
# speech    thank you for being here. let me say, my frien...
# dtype: object

# %%
scraped_df = df_sanders.apply(scrape_page,axis=1)

# %%
scraped_df.to_csv("sanders_speech.csv", index=False)

# %%
df_sanders = df_sanders.merge(scraped_df, left_index=True, right_index=True)
df_sanders
# Out:
#         date                                              place  \
# 0 2019-06-23                       Town Hall at Clinton College
# 1 2019-06-22       South Carolina Democratic Party Convention:
# 2 2019-06-12                    Remarks on Democratic Socialism
# 4 2019-05-25                       Rally in Montpelier, Vermont
# 5 2019-05-04                                            in Iowa
# 6 2019-04-12  Senator Sanders Campaign Rally in Madison, Wis...
# 7 2019-03-10           Campaign Event in Concord, New Hampshire
# 8 2019-03-02                 Presidential Campaign Announcement
# 9 2019-02-19                 Presidential Campaign Announcement
#
#                                              summary  \
# 0  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 4  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 5  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 6  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 7  Senator Bernie Sanders (I-VT) hosted a rally i...
# 8  Senator Bernie Sanders (I-VT) formally announc...
# 9  Senator Bernie Sanders (I-VT), a 2016 Democrat...
#
#                                                  url  \
# 0  /?461881-1/senator-bernie-sanders-town-hall-cl...
# 1  /?461983-8/south-carolina-democratic-party-con...
# 2  /?461581-1/senator-bernie-sanders-delivers-rem...
# 4  /?460966-1/senator-bernie-sanders-rally-montpe...
# 5  /?460388-1/senator-bernie-sanders-campaigns-am...
# 6  /?459755-1/senator-bernie-sanders-campaigns-ma...
# 7  /?458676-1/senator-bernie-sanders-campaigns-ha...
# 8  /?458403-1/senator-bernie-sanders-launches-pre...
# 9  /?458032-1/senator-bernie-sanders-announces-20...
#
#                                               speech
# 0  of the white house? [cheers and applause] well...
# 1  hello south carolina democrats. my name is kir...
# 2  thank you for being here. let me say, my frien...
# 4  hello, everybody! it is a great honor to be he...
# 5  i hate to let you down. this is not bernie. [c...
# 6  up next, senator bernie sanders hold as rally ...
# 7  thank you all. thank you. i know we new englan...
# 8  let me thank you all for a wonderful rendition...
# 9  senator bernie sanders released a video announ...

# %%
df_sanders.to_csv("sanders_info_speech.csv", index=False)

# %% [markdown]
# ### 2.3. Copy from Sanders' facebook event page and use regrex in visual studio to get sanders_events.txt

# %%
colnames=['date', 'city']

# %%
df_sanders_events = pd.read_csv("sanders_events.txt", sep=',',names=colnames)
df_sanders_events['date'] = pd.to_datetime(df_sanders_events['date'])
df_sanders_events
# Out:
#          date                city
# 0  2019-06-23       Rock Hill, SC
# 1  2019-06-22        Columbia, SC
# 2  2019-06-20         Laconia, NH
# 3  2019-06-20      Portsmouth, NH
# 4  2019-06-20           Keene, NH
# 5  2019-06-20          Nashua, NH
# 6  2019-06-20         Concord, NH
# 7  2019-06-20        Hooksett, NH
# 8  2019-06-20           Dover, NH
# 9  2019-06-16       Iowa City, IA
# 10 2019-06-15          Rapids, IA
# 11 2019-06-15         Ottumwa, IA
# 12 2019-06-15        Waterloo, IA
# 13 2019-06-15          Bluffs, IA
# 14 2019-06-15            Ames, IA
# 15 2019-06-14      Des Moines, IA
# 16 2019-06-09         Dubuque, IA
# 17 2019-06-08        Waterloo, IA
# 18 2019-06-08  Marchshalltown, IA
# 19 2019-06-08     Des Moines, IA
# 20 2019-06-01       San Jose, CA
# 21 2019-05-31       Pasadena, CA
# 22 2019-05-30       Las Vegas, NV
# 23 2019-05-29           Reno, NV
# 24 2019-05-28      Manchester, NH
# 25 2019-05-28     Londonderry, NH
# 26 2019-05-28         Concord, NH
# 27 2019-05-27    Rollinsford, NH
# 28 2019-05-27        Laconia, NH
# 29 2019-05-27          Warner, NH
# ..        ...                 ...
# 37 2019-05-17       Asheville, NC
# 38 2019-05-05      Sioux City, IA
# 39 2019-05-05        Spencer, IA
# 40 2019-05-04          Fort Dodge
# 41 2019-05-04      Bldg Perry, IA
# 42 2019-05-04            Ames, IA
# 43 2019-04-25           Worth, TX
# 44 2019-04-24        DHouston, TX
# 45 2019-04-19      Greenville, SC
# 46 2019-04-14      Pittsburgh, PA
# 47 2019-04-13         Warren, MI
# 48 2019-04-12         Madison, WI
# 49 2019-04-07          Malcom, IA
# 50 2019-04-07       Oskaloosa, IA
# 51 2019-04-06     Fairfield, Iowa
# 52 2019-04-06      Burlington, IA
# 53 2019-04-06           Muscatine
# 54 2019-04-05       Davenport, IA
# 55 2019-03-24   San Francisco, CA
# 56 2019-03-23     Los Angeles, CA
# 57 2019-03-22       San Diego, CA
# 58 2019-03-16           Henderson
# 59 2019-03-14      Charleston, SC
# 60 2019-03-10           Keene, NH
# 61 2019-03-10         Concord, NH
# 62 2019-03-09      Des Moines, IA
# 63 2019-03-08       Iowa City, IA
# 64 2019-03-07          Bluffs, IA
# 65 2019-03-03         Chicago, IL
# 66 2019-03-02        New York, NY
#
# [67 rows x 2 columns]

# %% [markdown]
# ### 2.4. Merge Sanders' event info and speech info together

# %%
df_sanders = df_sanders_events.merge(df_sanders, on='date', how='left')

# %%
df_sanders
# Out:
#          date                city  \
# 0  2019-06-23       Rock Hill, SC
# 1  2019-06-22        Columbia, SC
# 2  2019-06-20         Laconia, NH
# 3  2019-06-20      Portsmouth, NH
# 4  2019-06-20           Keene, NH
# 5  2019-06-20          Nashua, NH
# 6  2019-06-20         Concord, NH
# 7  2019-06-20        Hooksett, NH
# 8  2019-06-20           Dover, NH
# 9  2019-06-16       Iowa City, IA
# 10 2019-06-15          Rapids, IA
# 11 2019-06-15         Ottumwa, IA
# 12 2019-06-15        Waterloo, IA
# 13 2019-06-15          Bluffs, IA
# 14 2019-06-15            Ames, IA
# 15 2019-06-14      Des Moines, IA
# 16 2019-06-09         Dubuque, IA
# 17 2019-06-08        Waterloo, IA
# 18 2019-06-08  Marchshalltown, IA
# 19 2019-06-08     Des Moines, IA
# 20 2019-06-01       San Jose, CA
# 21 2019-05-31       Pasadena, CA
# 22 2019-05-30       Las Vegas, NV
# 23 2019-05-29           Reno, NV
# 24 2019-05-28      Manchester, NH
# 25 2019-05-28     Londonderry, NH
# 26 2019-05-28         Concord, NH
# 27 2019-05-27    Rollinsford, NH
# 28 2019-05-27        Laconia, NH
# 29 2019-05-27          Warner, NH
# ..        ...                 ...
# 37 2019-05-17       Asheville, NC
# 38 2019-05-05      Sioux City, IA
# 39 2019-05-05        Spencer, IA
# 40 2019-05-04          Fort Dodge
# 41 2019-05-04      Bldg Perry, IA
# 42 2019-05-04            Ames, IA
# 43 2019-04-25           Worth, TX
# 44 2019-04-24        DHouston, TX
# 45 2019-04-19      Greenville, SC
# 46 2019-04-14      Pittsburgh, PA
# 47 2019-04-13         Warren, MI
# 48 2019-04-12         Madison, WI
# 49 2019-04-07          Malcom, IA
# 50 2019-04-07       Oskaloosa, IA
# 51 2019-04-06     Fairfield, Iowa
# 52 2019-04-06      Burlington, IA
# 53 2019-04-06           Muscatine
# 54 2019-04-05       Davenport, IA
# 55 2019-03-24   San Francisco, CA
# 56 2019-03-23     Los Angeles, CA
# 57 2019-03-22       San Diego, CA
# 58 2019-03-16           Henderson
# 59 2019-03-14      Charleston, SC
# 60 2019-03-10           Keene, NH
# 61 2019-03-10         Concord, NH
# 62 2019-03-09      Des Moines, IA
# 63 2019-03-08       Iowa City, IA
# 64 2019-03-07          Bluffs, IA
# 65 2019-03-03         Chicago, IL
# 66 2019-03-02        New York, NY
#
#                                                 place  \
# 0                        Town Hall at Clinton College
# 1        South Carolina Democratic Party Convention:
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                            in Iowa
# 41                                            in Iowa
# 42                                            in Iowa
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  Senator Sanders Campaign Rally in Madison, Wis...
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60           Campaign Event in Concord, New Hampshire
# 61           Campaign Event in Concord, New Hampshire
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                 Presidential Campaign Announcement
#
#                                               summary  \
# 0   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1   Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 41  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 42  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60  Senator Bernie Sanders (I-VT) hosted a rally i...
# 61  Senator Bernie Sanders (I-VT) hosted a rally i...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66  Senator Bernie Sanders (I-VT) formally announc...
#
#                                                   url  \
# 0   /?461881-1/senator-bernie-sanders-town-hall-cl...
# 1   /?461983-8/south-carolina-democratic-party-con...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  /?460388-1/senator-bernie-sanders-campaigns-am...
# 41  /?460388-1/senator-bernie-sanders-campaigns-am...
# 42  /?460388-1/senator-bernie-sanders-campaigns-am...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  /?459755-1/senator-bernie-sanders-campaigns-ma...
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60  /?458676-1/senator-bernie-sanders-campaigns-ha...
# 61  /?458676-1/senator-bernie-sanders-campaigns-ha...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66  /?458403-1/senator-bernie-sanders-launches-pre...
#
#                                                speech
# 0   of the white house? [cheers and applause] well...
# 1   hello south carolina democrats. my name is kir...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  i hate to let you down. this is not bernie. [c...
# 41  i hate to let you down. this is not bernie. [c...
# 42  i hate to let you down. this is not bernie. [c...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  up next, senator bernie sanders hold as rally ...
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60  thank you all. thank you. i know we new englan...
# 61  thank you all. thank you. i know we new englan...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66  let me thank you all for a wonderful rendition...
#
# [67 rows x 6 columns]

# %%
del df_sanders['place']

# %%
df_sanders.head()
# Out:
#         date            city  \
# 0 2019-06-23   Rock Hill, SC
# 1 2019-06-22    Columbia, SC
# 2 2019-06-20     Laconia, NH
# 3 2019-06-20  Portsmouth, NH
# 4 2019-06-20       Keene, NH
#
#                                              summary  \
# 0  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 1  Senator Bernie Sanders (I-VT), a 2020 Democrat...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  url  \
# 0  /?461881-1/senator-bernie-sanders-town-hall-cl...
# 1  /?461983-8/south-carolina-democratic-party-con...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               speech
# 0  of the white house? [cheers and applause] well...
# 1  hello south carolina democrats. my name is kir...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_sanders.to_csv("sanders.csv", index=False)

# %% [markdown]
# ## 3. Repeat the above procedures for another candicate Kamala Harris

# %%
url = "https://www.c-span.org/search/?empty-date=1&sdate=&edate=&searchtype=Videos&sort=Most+Recent+Airing&text=0&&personid%5B%5D=1018696&formatid%5B%5D=55&show100="
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
rows = []
videos = doc.find(class_="video-results").find_all('li')
for video in videos:
    row={}
    try:
        row['date'] = video.find(class_="time").text
    except:
        pass
    try:
        row['place'] = video.find('h3').text
    except:
        pass
    try:
        row['summary'] = video.find(class_="abstract").text
    except:
        pass
    row['url'] = video.find('a')['href']
    rows.append(row)

# %%
df_harris = pd.DataFrame(rows)
df_harris['date'] = pd.to_datetime(df_harris['date'])

# %%
df[df['name'] == "Kamala D. Harris"]['kickoff_date']
# Out:
# 18   2019-01-21
# Name: kickoff_date, dtype: datetime64[ns]

# %%
df_harris = df_harris[df_harris['date'] > '2019-01-20']

# %%
df_harris
# Out:
#         date                                              place  \
# 0 2019-07-03  Senator Kamala Harris Town Hall in Des Moines,...
# 1 2019-06-22  South Carolina Democratic Party Convention: Se...
# 2 2019-06-09           Iowa Democratic Party Hall of Fame Forum
# 3 2019-04-23  Senator Kamala Harris Town Hall in Hanover, Ne...
# 5 2019-02-19  Politics and Eggs Breakfast with Senator Kamal...
# 6 2019-02-18  Senator Kamala Harris Town Hall in Portsmouth,...
#
#                                              summary  \
# 0  Senator Kamala Harris (D-CA), a 2020 Democrati...
# 1  Senator Kamala Harris (D-CA), a 2020 Democrati...
# 2  The Iowa Democratic Party held its Hall of Fam...
# 3  Democratic presidential candidate and U.S. Sen...
# 5  Senator Kamala Harris (D-CA), a 2020 president...
# 6  Senator Kamala Harris (D-CA) held a town hall ...
#
#                                                  url
# 0  //www.c-span.org/video/?462218-1/senator-kamal...
# 1  //www.c-span.org/video/?461983-2/south-carolin...
# 2  //www.c-span.org/video/?461356-1/white-house-h...
# 3  //www.c-span.org/video/?459979-1/senator-kamal...
# 5  //www.c-span.org/video/?457898-1/senator-kamal...
# 6  //www.c-span.org/video/?457973-1/senator-kamal...

# %%
df_harris.to_csv("harris_info.csv", index=False)

# %%
def scrape_page(row):
    url_harris = f"https:{row['url']}"
    
    from selenium import webdriver
    driver = webdriver.Chrome()
    driver.get(url_harris)
    
    buttons = driver.find_elements_by_class_name("link-show-full-text")
    for button in buttons:
        button.click()
    
    page = {}
    page['speech'] = '\n'.join([transcript.text.lower() for transcript in driver.find_elements_by_class_name("short_transcript")])
    
    return pd.Series(page)

# %%
scrape_page(df_harris.loc[0])
# Out:
# speech    the first african-american and first woman to ...
# dtype: object

# %%
scraped_df = df_harris.apply(scrape_page,axis=1)

# %%
df_harris = df_harris.merge(scraped_df, left_index=True, right_index=True)

# %%
df_harris
# Out:
#         date                                              place  \
# 0 2019-07-03  Senator Kamala Harris Town Hall in Des Moines,...
# 1 2019-06-22  South Carolina Democratic Party Convention: Se...
# 2 2019-06-09           Iowa Democratic Party Hall of Fame Forum
# 3 2019-04-23  Senator Kamala Harris Town Hall in Hanover, Ne...
# 5 2019-02-19  Politics and Eggs Breakfast with Senator Kamal...
# 6 2019-02-18  Senator Kamala Harris Town Hall in Portsmouth,...
#
#                                              summary  \
# 0  Senator Kamala Harris (D-CA), a 2020 Democrati...
# 1  Senator Kamala Harris (D-CA), a 2020 Democrati...
# 2  The Iowa Democratic Party held its Hall of Fam...
# 3  Democratic presidential candidate and U.S. Sen...
# 5  Senator Kamala Harris (D-CA), a 2020 president...
# 6  Senator Kamala Harris (D-CA) held a town hall ...
#
#                                                  url  \
# 0  //www.c-span.org/video/?462218-1/senator-kamal...
# 1  //www.c-span.org/video/?461983-2/south-carolin...
# 2  //www.c-span.org/video/?461356-1/white-house-h...
# 3  //www.c-span.org/video/?459979-1/senator-kamal...
# 5  //www.c-span.org/video/?457898-1/senator-kamal...
# 6  //www.c-span.org/video/?457973-1/senator-kamal...
#
#                                               speech
# 0  the first african-american and first woman to ...
# 1  what's up, south carolina? it's good to be in ...
# 2
# 3  senator kamala harris officially launched her ...
# 5  and the people will hear all of it. [cheers an...
# 6  our mission statement states that we celebrate...

# %%
df_harris.to_csv("harris_info_speech.csv", index=False)

# %%
colnames=['date', 'city']

# %%
df_harris_events = pd.read_csv("harris_events", sep=',',names=colnames)
df_harris_events['date'] = pd.to_datetime(df_harris_events['date'])
df_harris_events
# Out:
#          date                  city
# 0  2019-06-15         Las Vegas, NV
# 1  2019-06-13          Columbia, SC
# 2  2019-06-10           Dubuque, IA
# 3  2019-06-09          Waterloo, IA
# 4  2019-05-29        Greenville, SC
# 5  2019-05-29          Anderson, SC
# 6  2019-05-19   California City, CA
# 7  2019-05-15            Nashua, NH
# 8  2019-04-23           Hanover, NH
# 9  2019-04-23             Keene, NH
# 10 2019-04-20        Orangeburg, SC
# 11 2019-04-19         Rock Hill, SC
# 12 2019-04-10         Iowa City, IA
# 13 2019-03-24           Atlanta, GA
# 14 2019-03-23           Houston, TX
# 15 2019-03-01   North Las Vegas, NV
# 16 2019-02-24        Bettendorf, IA
# 17 2019-02-23            Ankeny, IA
# 18 2019-02-18        Portsmouth, NH
# 19 2019-02-16     West Columbia, SC
# 20 2019-02-15  North Charleston, SC
# 21 2019-01-28        Des Moines, IA
# 22 2019-01-27           Oakland, CA

# %%
df_harris = df_harris_events.merge(df_harris, on='date', how='left')

# %%
del df_harris['place']

# %%
df_harris
# Out:
#          date                  city  \
# 0  2019-06-15         Las Vegas, NV
# 1  2019-06-13          Columbia, SC
# 2  2019-06-10           Dubuque, IA
# 3  2019-06-09          Waterloo, IA
# 4  2019-05-29        Greenville, SC
# 5  2019-05-29          Anderson, SC
# 6  2019-05-19   California City, CA
# 7  2019-05-15            Nashua, NH
# 8  2019-04-23           Hanover, NH
# 9  2019-04-23             Keene, NH
# 10 2019-04-20        Orangeburg, SC
# 11 2019-04-19         Rock Hill, SC
# 12 2019-04-10         Iowa City, IA
# 13 2019-03-24           Atlanta, GA
# 14 2019-03-23           Houston, TX
# 15 2019-03-01   North Las Vegas, NV
# 16 2019-02-24        Bettendorf, IA
# 17 2019-02-23            Ankeny, IA
# 18 2019-02-18        Portsmouth, NH
# 19 2019-02-16     West Columbia, SC
# 20 2019-02-15  North Charleston, SC
# 21 2019-01-28        Des Moines, IA
# 22 2019-01-27           Oakland, CA
#
#                                               summary  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   The Iowa Democratic Party held its Hall of Fam...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Democratic presidential candidate and U.S. Sen...
# 9   Democratic presidential candidate and U.S. Sen...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Senator Kamala Harris (D-CA) held a town hall ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   //www.c-span.org/video/?461356-1/white-house-h...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   //www.c-span.org/video/?459979-1/senator-kamal...
# 9   //www.c-span.org/video/?459979-1/senator-kamal...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  //www.c-span.org/video/?457973-1/senator-kamal...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                speech
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   senator kamala harris officially launched her ...
# 9   senator kamala harris officially launched her ...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  our mission statement states that we celebrate...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN

# %%
df_sanders.to_csv("harris.csv", index=False)

# %% [markdown]
# ## 4. Repeat the above procedures for another candicate Andrew Yang, except that Yang's event schedule is provided by his campagin team, which was cleaned through visual studio too

# %%
url = "https://www.c-span.org/search/?empty-date=1&sdate=&edate=&searchtype=Videos&sort=Most+Recent+Airing&text=0&&personid%5B%5D=96807&formatid%5B%5D=55&show100="

response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
rows = []
videos = doc.find(class_="video-results").find_all('li')
for video in videos:
    row={}
    try:
        row['date'] = video.find(class_="time").text
    except:
        pass
    try:
        row['place'] = video.find('h3').text
    except:
        pass
    try:
        row['summary'] = video.find(class_="abstract").text
    except:
        pass
    row['url'] = video.find('a')['href']
    rows.append(row)

# %%
df_yang = pd.DataFrame(rows)
df_yang = df_yang[0:4]
df_yang['date'] = pd.to_datetime(df_yang['date'])
df_yang
# Out:
#         date                                              place  \
# 0 2019-06-22  South Carolina Democratic Party Convention: Se...
# 1 2019-06-09           Iowa Democratic Party Hall of Fame Forum
# 2 2019-04-15              Andrew Yang Rally at Lincoln Memorial
# 3 2019-03-20             Andrew Yang in Plymouth, New Hampshire
#
#                                              summary  \
# 0  Senator Kirsten Gillibrand (D-NY) , Andrew Yan...
# 1  The Iowa Democratic Party held its Hall of Fam...
# 2  Andrew Yang, a 2020 Democratic presidential ca...
# 3  Andrew Yang, a technology entrepreneur and 202...
#
#                                                  url
# 0  //www.c-span.org/video/?461983-9/south-carolin...
# 1  //www.c-span.org/video/?461356-1/white-house-h...
# 2  //www.c-span.org/video/?459819-1/democratic-pr...
# 3  //www.c-span.org/video/?458963-1/andrew-yang-m...

# %%
df_yang.to_csv("yang_info.csv", index=False)

# %%
def scrape_page(row):
    url_yang = f"https:{row['url']}"
    
    from selenium import webdriver
    driver = webdriver.Chrome()
    driver.get(url_yang)
    
    buttons = driver.find_elements_by_class_name("link-show-full-text")
    for button in buttons:
        button.click()
    
    page = {}
    page['speech'] = '\n'.join([transcript.text.lower() for transcript in driver.find_elements_by_class_name("short_transcript")])
    
    return pd.Series(page)

# %%
scrape_page(df_yang.loc[1])
# Out:
# speech    i have a lot of challenges with falling asleep...
# dtype: object

# %%
scraped_df = df_yang.apply(scrape_page,axis=1)
scraped_df
# Out:
#                                               speech
# 0  greetings. greetings. my name is jay inslee. i...
# 1  i have a lot of challenges with falling asleep...
# 2  let's see what our viewers are thinking about....
# 3  andrew yang is running for the democratic nomi...

# %%
df_yang = df_yang.merge(scraped_df, left_index=True, right_index=True)
df_yang
# Out:
#         date                                              place  \
# 0 2019-06-22  South Carolina Democratic Party Convention: Se...
# 1 2019-06-09           Iowa Democratic Party Hall of Fame Forum
# 2 2019-04-15              Andrew Yang Rally at Lincoln Memorial
# 3 2019-03-20             Andrew Yang in Plymouth, New Hampshire
#
#                                              summary  \
# 0  Senator Kirsten Gillibrand (D-NY) , Andrew Yan...
# 1  The Iowa Democratic Party held its Hall of Fam...
# 2  Andrew Yang, a 2020 Democratic presidential ca...
# 3  Andrew Yang, a technology entrepreneur and 202...
#
#                                                  url  \
# 0  //www.c-span.org/video/?461983-9/south-carolin...
# 1  //www.c-span.org/video/?461356-1/white-house-h...
# 2  //www.c-span.org/video/?459819-1/democratic-pr...
# 3  //www.c-span.org/video/?458963-1/andrew-yang-m...
#
#                                               speech
# 0  greetings. greetings. my name is jay inslee. i...
# 1  i have a lot of challenges with falling asleep...
# 2  let's see what our viewers are thinking about....
# 3  andrew yang is running for the democratic nomi...

# %%
df_yang.to_csv("yang_info_speech.csv", index=False)

# %%
colnames=['date', 'city']

# %%
df_yang_events = pd.read_csv("yang_events", sep=',',names=colnames)

# %%
df_yang_events['date'] = pd.to_datetime(df_yang_events['date'])

# %%
df_yang_events
# Out:
#          date                   city
# 0  2019-06-14              Dover, NH
# 1  2019-06-13       West Ossipee, NH
# 2  2019-05-18           Columbia, SC
# 3  2019-05-11            Windham, NH
# 4  2019-05-14           New York, NY
# 5  2019-05-11            Milford, NH
# 6  2019-05-11          Claremont, NH
# 7  2019-05-10         Portsmouth, NH
# 8  2019-05-09            Hanover, NH
# 9  2019-05-09            Lebanon, NH
# 10 2019-05-05        Minneapolis, MN
# 11 2019-05-04      Detroit, Michigan
# 12 2019-05-03            Seattle, WA
# 13 2019-04-28         Des Moines, IA
# 14 2019-04-27             Stuart, IA
# 15 2019-04-26         Sioux City, IA
# 16 2019-04-23          Las Vegas, NV
# 17 2019-04-22        Los Angeles, CA
# 18 2019-04-18            Atlanta, GA
# 19 2019-04-15          Washington DC
# 20 2019-04-10             Boston, MA
# 21 2019-03-25            Chicago, IL
# 22 2019-04-07            Concord, NH
# 23 2019-03-22          Littleton, NH
# 24 2019-03-20           Plymouth, NH
# 25 2019-03-21  West Stewartstown, NH
# 26 2019-03-15      San Francisco, CA
# 27 2019-03-12     Marchshalltown, IA
# 28 2019-03-13       Cedar Rapids, IA
# 29 2019-02-24           Mayfield, OH
# 30 2019-03-04         Washington, NJ
# 31 2019-02-18          Baltimore, MD
# 32 2019-02-06          Dunbarton, NH
# 33 2019-02-06            Laconia, NH
# 34 2019-02-06          Goffstown, NH
# 35 2019-02-06             Nashua, NH
# 36 2019-02-05            Raymond, NH
# 37 2019-02-05              Keene, NH
# 38 2019-02-01            Carroll, IA
# 39 2019-02-01            Denison, IA
# 40 2019-02-01          Jefferson, IA
# 41 2019-01-31              Pella, IA
# 42 2019-01-31          Indianola, IA
# 43 2019-01-29        Minneapolis, MN

# %%
df_yang = df_yang_events.merge(df_yang, on='date', how='left')

# %%
del df_yang['place']

# %%
df_yang
# Out:
#          date                   city  \
# 0  2019-06-14              Dover, NH
# 1  2019-06-13       West Ossipee, NH
# 2  2019-05-18           Columbia, SC
# 3  2019-05-11            Windham, NH
# 4  2019-05-14           New York, NY
# 5  2019-05-11            Milford, NH
# 6  2019-05-11          Claremont, NH
# 7  2019-05-10         Portsmouth, NH
# 8  2019-05-09            Hanover, NH
# 9  2019-05-09            Lebanon, NH
# 10 2019-05-05        Minneapolis, MN
# 11 2019-05-04      Detroit, Michigan
# 12 2019-05-03            Seattle, WA
# 13 2019-04-28         Des Moines, IA
# 14 2019-04-27             Stuart, IA
# 15 2019-04-26         Sioux City, IA
# 16 2019-04-23          Las Vegas, NV
# 17 2019-04-22        Los Angeles, CA
# 18 2019-04-18            Atlanta, GA
# 19 2019-04-15          Washington DC
# 20 2019-04-10             Boston, MA
# 21 2019-03-25            Chicago, IL
# 22 2019-04-07            Concord, NH
# 23 2019-03-22          Littleton, NH
# 24 2019-03-20           Plymouth, NH
# 25 2019-03-21  West Stewartstown, NH
# 26 2019-03-15      San Francisco, CA
# 27 2019-03-12     Marchshalltown, IA
# 28 2019-03-13       Cedar Rapids, IA
# 29 2019-02-24           Mayfield, OH
# 30 2019-03-04         Washington, NJ
# 31 2019-02-18          Baltimore, MD
# 32 2019-02-06          Dunbarton, NH
# 33 2019-02-06            Laconia, NH
# 34 2019-02-06          Goffstown, NH
# 35 2019-02-06             Nashua, NH
# 36 2019-02-05            Raymond, NH
# 37 2019-02-05              Keene, NH
# 38 2019-02-01            Carroll, IA
# 39 2019-02-01            Denison, IA
# 40 2019-02-01          Jefferson, IA
# 41 2019-01-31              Pella, IA
# 42 2019-01-31          Indianola, IA
# 43 2019-01-29        Minneapolis, MN
#
#                                               summary  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Andrew Yang, a 2020 Democratic presidential ca...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  Andrew Yang, a technology entrepreneur and 202...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
#
#                                                   url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  //www.c-span.org/video/?459819-1/democratic-pr...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  //www.c-span.org/video/?458963-1/andrew-yang-m...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
#
#                                                speech
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  let's see what our viewers are thinking about....
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  andrew yang is running for the democratic nomi...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN

# %%
df_yang.to_csv("yang.csv", index=False)

# %% [markdown]
# ## 5. Using Google maps API to get geometries of cities

# %% [markdown]
# ### 5.1. Get the API key of google map

# %%
import os
import time

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/leiao/.pyenv/versions/3.7.1/lib/python3.7/site-packages (0.10.3)
# sqlalchemy-migrate 0.12.0 has requirement SQLAlchemy>=0.9.6, but you'll have sqlalchemy 0.7.10 which is incompatible.
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !touch .env

# %%
API_KEY = os.getenv("GMAP_API_KEY")

# %% [markdown]
# ### 5.2. Combine the data of three candidates into one dataframe, giving them each an id, and get all the cities of the dataframe

# %%
df_sanders['id'] = 1
df_sanders['candidate'] = 'Sanders'
df_sanders['color'] = "#FF2311"

df_harris['id'] = 2
df_harris['candidate'] = 'Harris'
df_harris['color'] = "#009800"

df_yang['id'] = 3
df_yang['candidate'] = 'Yang'
df_yang['color'] = "#470AF5"

# %%
df = df_sanders.append(df_harris)
df = df.append(df_yang)
df.to_csv('candidates.csv',index=False)

# %%
placenames = []
for city in df.city:
    placenames.append(city)
placenames
# Out:
# ['Rock Hill, SC',
#  'Columbia, SC',
#  'Laconia, NH',
#  'Portsmouth, NH',
#  'Keene, NH',
#  'Nashua, NH',
#  'Concord, NH',
#  'Hooksett, NH',
#  'Dover, NH',
#  'Iowa City, IA',
#  'Rapids, IA',
#  'Ottumwa, IA',
#  'Waterloo, IA',
#  'Bluffs, IA',
#  'Ames, IA',
#  'Des Moines, IA',
#  'Dubuque, IA',
#  'Waterloo, IA',
#  'Marchshalltown, IA',
#  'Des Moines, IA ',
#  'San Jose, CA ',
#  'Pasadena, CA ',
#  'Las Vegas, NV',
#  'Reno, NV ',
#  'Manchester, NH',
#  'Londonderry, NH',
#  'Concord, NH',
#  'Rollinsford, NH ',
#  'Laconia, NH ',
#  'Warner, NH',
#  'Montpelier, VT',
#  'Montgomery, AL',
#  'Birmingham, AL',
#  'Augusta, GA',
#  'DenMarchk, SC',
#  'Orangeburg, SC',
#  'Charlotte, NC ',
#  'Asheville, NC',
#  'Sioux City, IA',
#  'Spencer, IA ',
#  'Fort Dodge',
#  'Bldg Perry, IA',
#  'Ames, IA',
#  'Worth, TX',
#  'DHouston, TX',
#  'Greenville, SC',
#  'Pittsburgh, PA',
#  'Warren, MI ',
#  'Madison, WI',
#  'Malcom, IA',
#  'Oskaloosa, IA',
#  'Fairfield, Iowa',
#  'Burlington, IA',
#  'Muscatine',
#  'Davenport, IA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Diego, CA',
#  'Henderson',
#  'Charleston, SC',
#  'Keene, NH',
#  'Concord, NH',
#  'Des Moines, IA',
#  'Iowa City, IA',
#  'Bluffs, IA',
#  'Chicago, IL',
#  'New York, NY',
#  'Las Vegas, NV',
#  'Columbia, SC',
#  'Dubuque, IA',
#  'Waterloo, IA',
#  'Greenville, SC',
#  'Anderson, SC',
#  'California City, CA',
#  'Nashua, NH',
#  'Hanover, NH',
#  'Keene, NH',
#  'Orangeburg, SC',
#  'Rock Hill, SC',
#  'Iowa City, IA',
#  'Atlanta, GA',
#  'Houston, TX',
#  'North Las Vegas, NV',
#  'Bettendorf, IA',
#  'Ankeny, IA',
#  'Portsmouth, NH',
#  'West Columbia, SC',
#  'North Charleston, SC',
#  'Des Moines, IA',
#  'Oakland, CA',
#  'Dover, NH',
#  'West Ossipee, NH',
#  'Columbia, SC',
#  'Windham, NH',
#  'New York, NY',
#  'Milford, NH',
#  'Claremont, NH',
#  'Portsmouth, NH',
#  'Hanover, NH',
#  'Lebanon, NH',
#  'Minneapolis, MN',
#  'Detroit, Michigan',
#  'Seattle, WA',
#  'Des Moines, IA',
#  'Stuart, IA',
#  'Sioux City, IA',
#  'Las Vegas, NV',
#  'Los Angeles, CA',
#  'Atlanta, GA',
#  'Washington DC',
#  'Boston, MA',
#  'Chicago, IL',
#  'Concord, NH',
#  'Littleton, NH',
#  'Plymouth, NH',
#  'West Stewartstown, NH',
#  'San Francisco, CA',
#  'Marchshalltown, IA',
#  'Cedar Rapids, IA',
#  'Mayfield, OH',
#  'Washington, NJ',
#  'Baltimore, MD',
#  'Dunbarton, NH',
#  'Laconia, NH',
#  'Goffstown, NH',
#  'Nashua, NH',
#  'Raymond, NH',
#  'Keene, NH',
#  'Carroll, IA',
#  'Denison, IA',
#  'Jefferson, IA',
#  'Pella, IA',
#  'Indianola, IA',
#  'Minneapolis, MN']

# %% [markdown]
# ### 5.3. Get geometries of cities

# %%
geometry_df = []
for place in placenames:
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    keys = {'address': place, 'key': API_KEY}
    r = requests.get(url,params=keys)
    result_dic = r.json()
    lat = result_dic['results'][0]['geometry']['location']['lat']
    long = result_dic['results'][0]['geometry']['location']['lng']
    coords = []
    coords.append(long)
    coords.append(lat)
    mygeometry = {'place': place, 'geometry.type': 'Point','geometry.coordinates':coords}
    geometry_df.append(mygeometry)
    time.sleep(1)
geometry_df
# Out:
# [{'place': 'Rock Hill, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.02507840000001, 34.9248667]},
#  {'place': 'Columbia, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.0348144, 34.0007104]},
#  {'place': 'Laconia, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.4703509, 43.5278546]},
#  {'place': 'Portsmouth, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.7625532, 43.0717552]},
#  {'place': 'Keene, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2781409, 42.933692]},
#  {'place': 'Nashua, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.46756599999999, 42.7653662]},
#  {'place': 'Concord, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.5375718, 43.2081366]},
#  {'place': 'Hooksett, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.46512830000002, 43.0967213]},
#  {'place': 'Dover, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.8736698, 43.1978624]},
#  {'place': 'Iowa City, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.5301683, 41.6611277]},
#  {'place': 'Rapids, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.6656232, 41.9778795]},
#  {'place': 'Ottumwa, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.40830220000001, 41.01602930000001]},
#  {'place': 'Waterloo, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.34257749999999, 42.492786]},
#  {'place': 'Bluffs, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.8608333, 41.2619444]},
#  {'place': 'Ames, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.63191309999999, 42.0307812]},
#  {'place': 'Des Moines, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6249593, 41.5868353]},
#  {'place': 'Dubuque, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-90.66457179999999, 42.5005583]},
#  {'place': 'Waterloo, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.34257749999999, 42.492786]},
#  {'place': 'Marchshalltown, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.90803749999999, 42.0494674]},
#  {'place': 'Des Moines, IA ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6249593, 41.5868353]},
#  {'place': 'San Jose, CA ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-121.8863286, 37.3382082]},
#  {'place': 'Pasadena, CA ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-118.1445155, 34.1477849]},
#  {'place': 'Las Vegas, NV',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-115.1398296, 36.1699412]},
#  {'place': 'Reno, NV ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-119.8138027, 39.5296329]},
#  {'place': 'Manchester, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.4547891, 42.9956397]},
#  {'place': 'Londonderry, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.3739272, 42.86512980000001]},
#  {'place': 'Concord, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.5375718, 43.2081366]},
#  {'place': 'Rollinsford, NH ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.8203355, 43.2361957]},
#  {'place': 'Laconia, NH ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.4703509, 43.5278546]},
#  {'place': 'Warner, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.8334145, 43.2556568]},
#  {'place': 'Montpelier, VT',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.5753869, 44.26005929999999]},
#  {'place': 'Montgomery, AL',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-86.3077368, 32.3792233]},
#  {'place': 'Birmingham, AL',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-86.8103567, 33.5185892]},
#  {'place': 'Augusta, GA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-82.0105148, 33.4734978]},
#  {'place': 'DenMarchk, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.1423236, 33.3226546]},
#  {'place': 'Orangeburg, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-80.8556476, 33.4918203]},
#  {'place': 'Charlotte, NC ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-80.8431267, 35.2270869]},
#  {'place': 'Asheville, NC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-82.5514869, 35.5950581]},
#  {'place': 'Sioux City, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-96.40494079999999, 42.4963416]},
#  {'place': 'Spencer, IA ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.144318, 43.1450748]},
#  {'place': 'Fort Dodge',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-94.16801579999999, 42.4974694]},
#  {'place': 'Bldg Perry, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-94.0955769, 41.8423595]},
#  {'place': 'Ames, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.63191309999999, 42.0307812]},
#  {'place': 'Worth, TX',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-97.3307658, 32.7554883]},
#  {'place': 'DHouston, TX',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.3698028, 29.7604267]},
#  {'place': 'Greenville, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-82.3940104, 34.85261759999999]},
#  {'place': 'Pittsburgh, PA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-79.9958864, 40.44062479999999]},
#  {'place': 'Warren, MI ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-83.01465259999999, 42.5144566]},
#  {'place': 'Madison, WI',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-89.4012302, 43.0730517]},
#  {'place': 'Malcom, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.55907599999999, 41.70833020000001]},
#  {'place': 'Oskaloosa, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.6493595, 41.2916728]},
#  {'place': 'Fairfield, Iowa',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.9636914, 41.00761139999999]},
#  {'place': 'Burlington, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.1128901, 40.8076529]},
#  {'place': 'Muscatine',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.0432051, 41.424473]},
#  {'place': 'Davenport, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-90.5776367, 41.5236437]},
#  {'place': 'San Francisco, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-122.4194155, 37.7749295]},
#  {'place': 'Los Angeles, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-118.2436849, 34.0522342]},
#  {'place': 'San Diego, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-117.1610838, 32.715738]},
#  {'place': 'Henderson',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-114.9817213, 36.0395247]},
#  {'place': 'Charleston, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-79.93105120000001, 32.7764749]},
#  {'place': 'Keene, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2781409, 42.933692]},
#  {'place': 'Concord, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.5375718, 43.2081366]},
#  {'place': 'Des Moines, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6249593, 41.5868353]},
#  {'place': 'Iowa City, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.5301683, 41.6611277]},
#  {'place': 'Bluffs, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.8608333, 41.2619444]},
#  {'place': 'Chicago, IL',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-87.6297982, 41.8781136]},
#  {'place': 'New York, NY',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-74.0059728, 40.7127753]},
#  {'place': 'Las Vegas, NV',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-115.1398296, 36.1699412]},
#  {'place': 'Columbia, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.0348144, 34.0007104]},
#  {'place': 'Dubuque, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-90.66457179999999, 42.5005583]},
#  {'place': 'Waterloo, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.34257749999999, 42.492786]},
#  {'place': 'Greenville, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-82.3940104, 34.85261759999999]},
#  {'place': 'Anderson, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-82.6501332, 34.5034394]},
#  {'place': 'California City, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-117.9859038, 35.125801]},
#  {'place': 'Nashua, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.46756599999999, 42.7653662]},
#  {'place': 'Hanover, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2895526, 43.7022451]},
#  {'place': 'Keene, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2781409, 42.933692]},
#  {'place': 'Orangeburg, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-80.8556476, 33.4918203]},
#  {'place': 'Rock Hill, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.02507840000001, 34.9248667]},
#  {'place': 'Iowa City, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.5301683, 41.6611277]},
#  {'place': 'Atlanta, GA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-84.3879824, 33.7489954]},
#  {'place': 'Houston, TX',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.3698028, 29.7604267]},
#  {'place': 'North Las Vegas, NV',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-115.1175013, 36.1988592]},
#  {'place': 'Bettendorf, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-90.50725729999999, 41.5262641]},
#  {'place': 'Ankeny, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6001278, 41.7317884]},
#  {'place': 'Portsmouth, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.7625532, 43.0717552]},
#  {'place': 'West Columbia, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.0739825, 33.9934867]},
#  {'place': 'North Charleston, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-80.0130514, 32.8771106]},
#  {'place': 'Des Moines, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6249593, 41.5868353]},
#  {'place': 'Oakland, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-122.2711639, 37.8043514]},
#  {'place': 'Dover, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.8736698, 43.1978624]},
#  {'place': 'West Ossipee, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.20347009999999, 43.82184669999999]},
#  {'place': 'Columbia, SC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.0348144, 34.0007104]},
#  {'place': 'Windham, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.30422899999999, 42.8006441]},
#  {'place': 'New York, NY',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-74.0059728, 40.7127753]},
#  {'place': 'Milford, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.6489836, 42.8353619]},
#  {'place': 'Claremont, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.33787439999999, 43.3728635]},
#  {'place': 'Portsmouth, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-70.7625532, 43.0717552]},
#  {'place': 'Hanover, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2895526, 43.7022451]},
#  {'place': 'Lebanon, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2517569, 43.6422934]},
#  {'place': 'Minneapolis, MN',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.2650108, 44.977753]},
#  {'place': 'Detroit, Michigan',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-83.0457538, 42.331427]},
#  {'place': 'Seattle, WA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-122.3320708, 47.6062095]},
#  {'place': 'Des Moines, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.6249593, 41.5868353]},
#  {'place': 'Stuart, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-94.3183715, 41.5034243]},
#  {'place': 'Sioux City, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-96.40494079999999, 42.4963416]},
#  {'place': 'Las Vegas, NV',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-115.1398296, 36.1699412]},
#  {'place': 'Los Angeles, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-118.2436849, 34.0522342]},
#  {'place': 'Atlanta, GA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-84.3879824, 33.7489954]},
#  {'place': 'Washington DC',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-77.0368707, 38.9071923]},
#  {'place': 'Boston, MA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.0588801, 42.3600825]},
#  {'place': 'Chicago, IL',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-87.6297982, 41.8781136]},
#  {'place': 'Concord, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.5375718, 43.2081366]},
#  {'place': 'Littleton, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.7701237, 44.3061628]},
#  {'place': 'Plymouth, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.6881528, 43.7570196]},
#  {'place': 'West Stewartstown, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.5313768, 44.9954358]},
#  {'place': 'San Francisco, CA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-122.4194155, 37.7749295]},
#  {'place': 'Marchshalltown, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.90803749999999, 42.0494674]},
#  {'place': 'Cedar Rapids, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-91.6656232, 41.9778795]},
#  {'place': 'Mayfield, OH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-81.4392828, 41.5519952]},
#  {'place': 'Washington, NJ',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-74.9793378, 40.7584326]},
#  {'place': 'Baltimore, MD',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-76.6121893, 39.2903848]},
#  {'place': 'Dunbarton, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.6164615, 43.1025818]},
#  {'place': 'Laconia, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.4703509, 43.5278546]},
#  {'place': 'Goffstown, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.6002223, 43.0204052]},
#  {'place': 'Nashua, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.46756599999999, 42.7653662]},
#  {'place': 'Raymond, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-71.1833857, 43.0362094]},
#  {'place': 'Keene, NH',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-72.2781409, 42.933692]},
#  {'place': 'Carroll, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-94.86727929999999, 42.0655986]},
#  {'place': 'Denison, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-95.3588867, 42.024988]},
#  {'place': 'Jefferson, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-94.3774232, 42.0172457]},
#  {'place': 'Pella, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-92.91640500000001, 41.4080327]},
#  {'place': 'Indianola, IA',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.5574376, 41.3580484]},
#  {'place': 'Minneapolis, MN',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [-93.2650108, 44.977753]}]

# %%
geometry_df = pd.DataFrame(geometry_df)

# %%
geometry_df
# Out:
#                         geometry.coordinates geometry.type  \
# 0           [-81.02507840000001, 34.9248667]         Point
# 1                  [-81.0348144, 34.0007104]         Point
# 2                  [-71.4703509, 43.5278546]         Point
# 3                  [-70.7625532, 43.0717552]         Point
# 4                   [-72.2781409, 42.933692]         Point
# 5           [-71.46756599999999, 42.7653662]         Point
# 6                  [-71.5375718, 43.2081366]         Point
# 7           [-71.46512830000002, 43.0967213]         Point
# 8                  [-70.8736698, 43.1978624]         Point
# 9                  [-91.5301683, 41.6611277]         Point
# 10                 [-91.6656232, 41.9778795]         Point
# 11   [-92.40830220000001, 41.01602930000001]         Point
# 12           [-92.34257749999999, 42.492786]         Point
# 13                 [-95.8608333, 41.2619444]         Point
# 14          [-93.63191309999999, 42.0307812]         Point
# 15                 [-93.6249593, 41.5868353]         Point
# 16          [-90.66457179999999, 42.5005583]         Point
# 17           [-92.34257749999999, 42.492786]         Point
# 18          [-92.90803749999999, 42.0494674]         Point
# 19                 [-93.6249593, 41.5868353]         Point
# 20                [-121.8863286, 37.3382082]         Point
# 21                [-118.1445155, 34.1477849]         Point
# 22                [-115.1398296, 36.1699412]         Point
# 23                [-119.8138027, 39.5296329]         Point
# 24                 [-71.4547891, 42.9956397]         Point
# 25          [-71.3739272, 42.86512980000001]         Point
# 26                 [-71.5375718, 43.2081366]         Point
# 27                 [-70.8203355, 43.2361957]         Point
# 28                 [-71.4703509, 43.5278546]         Point
# 29                 [-71.8334145, 43.2556568]         Point
# ..                                       ...           ...
# 104                [-94.3183715, 41.5034243]         Point
# 105         [-96.40494079999999, 42.4963416]         Point
# 106               [-115.1398296, 36.1699412]         Point
# 107               [-118.2436849, 34.0522342]         Point
# 108                [-84.3879824, 33.7489954]         Point
# 109                [-77.0368707, 38.9071923]         Point
# 110                [-71.0588801, 42.3600825]         Point
# 111                [-87.6297982, 41.8781136]         Point
# 112                [-71.5375718, 43.2081366]         Point
# 113                [-71.7701237, 44.3061628]         Point
# 114                [-71.6881528, 43.7570196]         Point
# 115                [-71.5313768, 44.9954358]         Point
# 116               [-122.4194155, 37.7749295]         Point
# 117         [-92.90803749999999, 42.0494674]         Point
# 118                [-91.6656232, 41.9778795]         Point
# 119                [-81.4392828, 41.5519952]         Point
# 120                [-74.9793378, 40.7584326]         Point
# 121                [-76.6121893, 39.2903848]         Point
# 122                [-71.6164615, 43.1025818]         Point
# 123                [-71.4703509, 43.5278546]         Point
# 124                [-71.6002223, 43.0204052]         Point
# 125         [-71.46756599999999, 42.7653662]         Point
# 126                [-71.1833857, 43.0362094]         Point
# 127                 [-72.2781409, 42.933692]         Point
# 128         [-94.86727929999999, 42.0655986]         Point
# 129                 [-95.3588867, 42.024988]         Point
# 130                [-94.3774232, 42.0172457]         Point
# 131         [-92.91640500000001, 41.4080327]         Point
# 132                [-93.5574376, 41.3580484]         Point
# 133                 [-93.2650108, 44.977753]         Point
#
#                      place
# 0            Rock Hill, SC
# 1             Columbia, SC
# 2              Laconia, NH
# 3           Portsmouth, NH
# 4                Keene, NH
# 5               Nashua, NH
# 6              Concord, NH
# 7             Hooksett, NH
# 8                Dover, NH
# 9            Iowa City, IA
# 10              Rapids, IA
# 11             Ottumwa, IA
# 12            Waterloo, IA
# 13              Bluffs, IA
# 14                Ames, IA
# 15          Des Moines, IA
# 16             Dubuque, IA
# 17            Waterloo, IA
# 18      Marchshalltown, IA
# 19         Des Moines, IA
# 20           San Jose, CA
# 21           Pasadena, CA
# 22           Las Vegas, NV
# 23               Reno, NV
# 24          Manchester, NH
# 25         Londonderry, NH
# 26             Concord, NH
# 27        Rollinsford, NH
# 28            Laconia, NH
# 29              Warner, NH
# ..                     ...
# 104             Stuart, IA
# 105         Sioux City, IA
# 106          Las Vegas, NV
# 107        Los Angeles, CA
# 108            Atlanta, GA
# 109          Washington DC
# 110             Boston, MA
# 111            Chicago, IL
# 112            Concord, NH
# 113          Littleton, NH
# 114           Plymouth, NH
# 115  West Stewartstown, NH
# 116      San Francisco, CA
# 117     Marchshalltown, IA
# 118       Cedar Rapids, IA
# 119           Mayfield, OH
# 120         Washington, NJ
# 121          Baltimore, MD
# 122          Dunbarton, NH
# 123            Laconia, NH
# 124          Goffstown, NH
# 125             Nashua, NH
# 126            Raymond, NH
# 127              Keene, NH
# 128            Carroll, IA
# 129            Denison, IA
# 130          Jefferson, IA
# 131              Pella, IA
# 132          Indianola, IA
# 133        Minneapolis, MN
#
# [134 rows x 3 columns]

# %% [markdown]
# ### 5.4. Merge the geometry data with the previous dataframe

# %%
df = df.merge(geometry_df, left_on='city',right_on='place')

# %%
df = df.sort_values(by="date", ascending=True)

# %%
df = df.drop_duplicates(subset=['date','candidate','city','url'], keep='first')

# %%
df = df.reset_index(drop=True)

# %%
df.rename(columns={'city': 'properties.name', 'speech': 'properties.article', 'date':'properties.headline', 'id':'properties.group_id','candidate':'properties.group_name', 'color':'properties.color'}, inplace=True)

# %%
df['properties.month']=df['properties.headline'].apply(lambda x: x.month)

# %%
df['properties.month']=df['properties.month'].apply(lambda x: calendar.month_name[x])

# %%
df = df[['geometry.coordinates', 'geometry.type', 'properties.headline','properties.month','properties.article','properties.group_name','properties.color','properties.group_id','properties.name']]

# %%
df['properties.headline'] = df['properties.headline'].astype(str)

# %%
df['properties.headline'] = df['properties.headline'] + ' || ' + df['properties.group_name'] + ' || ' + df['properties.name']

df['properties.article'] = df['properties.name'] + ' ' + df['properties.article'].map(str)

df['properties.article'] = df['properties.article'].str.replace('nan','')

# %%
df.dtypes
df.to_csv("geo-data.csv",index=False)
df
# Out:
#                         geometry.coordinates geometry.type  \
# 0                 [-122.2711639, 37.8043514]         Point
# 1                  [-93.6249593, 41.5868353]         Point
# 2                   [-93.2650108, 44.977753]         Point
# 3           [-92.91640500000001, 41.4080327]         Point
# 4                  [-93.5574376, 41.3580484]         Point
# 5           [-94.86727929999999, 42.0655986]         Point
# 6                   [-95.3588867, 42.024988]         Point
# 7                  [-94.3774232, 42.0172457]         Point
# 8                   [-72.2781409, 42.933692]         Point
# 9                  [-71.1833857, 43.0362094]         Point
# 10                 [-71.4703509, 43.5278546]         Point
# 11                 [-71.6164615, 43.1025818]         Point
# 12                 [-71.6002223, 43.0204052]         Point
# 13          [-71.46756599999999, 42.7653662]         Point
# 14                 [-80.0130514, 32.8771106]         Point
# 15                 [-81.0739825, 33.9934867]         Point
# 16                 [-76.6121893, 39.2903848]         Point
# 17                 [-70.7625532, 43.0717552]         Point
# 18                 [-93.6001278, 41.7317884]         Point
# 19                 [-81.4392828, 41.5519952]         Point
# 20          [-90.50725729999999, 41.5262641]         Point
# 21                [-115.1175013, 36.1988592]         Point
# 22                 [-74.0059728, 40.7127753]         Point
# 23                 [-87.6297982, 41.8781136]         Point
# 24                 [-74.9793378, 40.7584326]         Point
# 25                 [-95.8608333, 41.2619444]         Point
# 26                 [-91.5301683, 41.6611277]         Point
# 27                 [-93.6249593, 41.5868353]         Point
# 28                 [-71.5375718, 43.2081366]         Point
# 29                  [-72.2781409, 42.933692]         Point
# ..                                       ...           ...
# 104         [-82.3940104, 34.85261759999999]         Point
# 105               [-115.1398296, 36.1699412]         Point
# 106               [-118.1445155, 34.1477849]         Point
# 107               [-121.8863286, 37.3382082]         Point
# 108          [-92.34257749999999, 42.492786]         Point
# 109         [-92.90803749999999, 42.0494674]         Point
# 110                [-93.6249593, 41.5868353]         Point
# 111          [-92.34257749999999, 42.492786]         Point
# 112         [-90.66457179999999, 42.5005583]         Point
# 113         [-90.66457179999999, 42.5005583]         Point
# 114                [-81.0348144, 34.0007104]         Point
# 115  [-71.20347009999999, 43.82184669999999]         Point
# 116                [-70.8736698, 43.1978624]         Point
# 117                [-93.6249593, 41.5868353]         Point
# 118               [-115.1398296, 36.1699412]         Point
# 119                [-91.6656232, 41.9778795]         Point
# 120  [-92.40830220000001, 41.01602930000001]         Point
# 121          [-92.34257749999999, 42.492786]         Point
# 122                [-95.8608333, 41.2619444]         Point
# 123         [-93.63191309999999, 42.0307812]         Point
# 124                [-91.5301683, 41.6611277]         Point
# 125                 [-72.2781409, 42.933692]         Point
# 126                [-71.4703509, 43.5278546]         Point
# 127                [-70.7625532, 43.0717552]         Point
# 128         [-71.46512830000002, 43.0967213]         Point
# 129         [-71.46756599999999, 42.7653662]         Point
# 130                [-71.5375718, 43.2081366]         Point
# 131                [-70.8736698, 43.1978624]         Point
# 132                [-81.0348144, 34.0007104]         Point
# 133         [-81.02507840000001, 34.9248667]         Point
#
#                               properties.headline properties.month  \
# 0             2019-01-27 || Harris || Oakland, CA          January
# 1          2019-01-28 || Harris || Des Moines, IA          January
# 2           2019-01-29 || Yang || Minneapolis, MN          January
# 3                 2019-01-31 || Yang || Pella, IA          January
# 4             2019-01-31 || Yang || Indianola, IA          January
# 5               2019-02-01 || Yang || Carroll, IA         February
# 6               2019-02-01 || Yang || Denison, IA         February
# 7             2019-02-01 || Yang || Jefferson, IA         February
# 8                 2019-02-05 || Yang || Keene, NH         February
# 9               2019-02-05 || Yang || Raymond, NH         February
# 10              2019-02-06 || Yang || Laconia, NH         February
# 11            2019-02-06 || Yang || Dunbarton, NH         February
# 12            2019-02-06 || Yang || Goffstown, NH         February
# 13               2019-02-06 || Yang || Nashua, NH         February
# 14   2019-02-15 || Harris || North Charleston, SC         February
# 15      2019-02-16 || Harris || West Columbia, SC         February
# 16            2019-02-18 || Yang || Baltimore, MD         February
# 17         2019-02-18 || Harris || Portsmouth, NH         February
# 18             2019-02-23 || Harris || Ankeny, IA         February
# 19             2019-02-24 || Yang || Mayfield, OH         February
# 20         2019-02-24 || Harris || Bettendorf, IA         February
# 21    2019-03-01 || Harris || North Las Vegas, NV            March
# 22          2019-03-02 || Sanders || New York, NY            March
# 23           2019-03-03 || Sanders || Chicago, IL            March
# 24           2019-03-04 || Yang || Washington, NJ            March
# 25            2019-03-07 || Sanders || Bluffs, IA            March
# 26         2019-03-08 || Sanders || Iowa City, IA            March
# 27        2019-03-09 || Sanders || Des Moines, IA            March
# 28           2019-03-10 || Sanders || Concord, NH            March
# 29             2019-03-10 || Sanders || Keene, NH            March
# ..                                            ...              ...
# 104        2019-05-29 || Harris || Greenville, SC              May
# 105        2019-05-30 || Sanders || Las Vegas, NV              May
# 106        2019-05-31 || Sanders || Pasadena, CA               May
# 107        2019-06-01 || Sanders || San Jose, CA              June
# 108         2019-06-08 || Sanders || Waterloo, IA             June
# 109   2019-06-08 || Sanders || Marchshalltown, IA             June
# 110      2019-06-08 || Sanders || Des Moines, IA              June
# 111          2019-06-09 || Harris || Waterloo, IA             June
# 112          2019-06-09 || Sanders || Dubuque, IA             June
# 113           2019-06-10 || Harris || Dubuque, IA             June
# 114          2019-06-13 || Harris || Columbia, SC             June
# 115        2019-06-13 || Yang || West Ossipee, NH             June
# 116               2019-06-14 || Yang || Dover, NH             June
# 117       2019-06-14 || Sanders || Des Moines, IA             June
# 118         2019-06-15 || Harris || Las Vegas, NV             June
# 119           2019-06-15 || Sanders || Rapids, IA             June
# 120          2019-06-15 || Sanders || Ottumwa, IA             June
# 121         2019-06-15 || Sanders || Waterloo, IA             June
# 122           2019-06-15 || Sanders || Bluffs, IA             June
# 123             2019-06-15 || Sanders || Ames, IA             June
# 124        2019-06-16 || Sanders || Iowa City, IA             June
# 125            2019-06-20 || Sanders || Keene, NH             June
# 126          2019-06-20 || Sanders || Laconia, NH             June
# 127       2019-06-20 || Sanders || Portsmouth, NH             June
# 128         2019-06-20 || Sanders || Hooksett, NH             June
# 129           2019-06-20 || Sanders || Nashua, NH             June
# 130          2019-06-20 || Sanders || Concord, NH             June
# 131            2019-06-20 || Sanders || Dover, NH             June
# 132         2019-06-22 || Sanders || Columbia, SC             June
# 133        2019-06-23 || Sanders || Rock Hill, SC             June
#
#                                     properties.article properties.group_name  \
# 0                                         Oakland, CA                 Harris
# 1                                      Des Moines, IA                 Harris
# 2                                     Minneapolis, MN                   Yang
# 3                                           Pella, IA                   Yang
# 4                                       Indianola, IA                   Yang
# 5                                         Carroll, IA                   Yang
# 6                                         Denison, IA                   Yang
# 7                                       Jefferson, IA                   Yang
# 8                                           Keene, NH                   Yang
# 9                                         Raymond, NH                   Yang
# 10                                        Laconia, NH                   Yang
# 11                                      Dunbarton, NH                   Yang
# 12                                      Goffstown, NH                   Yang
# 13                                         Nashua, NH                   Yang
# 14                               North Charleston, SC                 Harris
# 15                                  West Columbia, SC                 Harris
# 16                                      Baltimore, MD                   Yang
# 17   Portsmouth, NH our mission statement states th...                Harris
# 18                                         Ankeny, IA                 Harris
# 19                                       Mayfield, OH                   Yang
# 20                                     Bettendorf, IA                 Harris
# 21                                North Las Vegas, NV                 Harris
# 22   New York, NY let me thank you all for a wonder...               Sanders
# 23                                        Chicago, IL                Sanders
# 24                                     Washington, NJ                   Yang
# 25                                         Bluffs, IA                Sanders
# 26                                      Iowa City, IA                Sanders
# 27                                     Des Moines, IA                Sanders
# 28   Concord, NH thank you all. thank you. i know w...               Sanders
# 29   Keene, NH thank you all. thank you. i know we ...               Sanders
# ..                                                 ...                   ...
# 104                                    Greenville, SC                 Harris
# 105                                     Las Vegas, NV                Sanders
# 106                                     Pasadena, CA                 Sanders
# 107                                     San Jose, CA                 Sanders
# 108                                      Waterloo, IA                Sanders
# 109                                Marchshalltown, IA                Sanders
# 110                                   Des Moines, IA                 Sanders
# 111                                      Waterloo, IA                 Harris
# 112                                       Dubuque, IA                Sanders
# 113                                       Dubuque, IA                 Harris
# 114                                      Columbia, SC                 Harris
# 115                                  West Ossipee, NH                   Yang
# 116                                         Dover, NH                   Yang
# 117                                    Des Moines, IA                Sanders
# 118                                     Las Vegas, NV                 Harris
# 119                                        Rapids, IA                Sanders
# 120                                       Ottumwa, IA                Sanders
# 121                                      Waterloo, IA                Sanders
# 122                                        Bluffs, IA                Sanders
# 123                                          Ames, IA                Sanders
# 124                                     Iowa City, IA                Sanders
# 125                                         Keene, NH                Sanders
# 126                                       Laconia, NH                Sanders
# 127                                    Portsmouth, NH                Sanders
# 128                                      Hooksett, NH                Sanders
# 129                                        Nashua, NH                Sanders
# 130                                       Concord, NH                Sanders
# 131                                         Dover, NH                Sanders
# 132  Columbia, SC hello south carolina democrats. m...               Sanders
# 133  Rock Hill, SC of the white house? [cheers and ...               Sanders
#
#     properties.color  properties.group_id       properties.name
# 0            #009800                    2           Oakland, CA
# 1            #009800                    2        Des Moines, IA
# 2            #470AF5                    3       Minneapolis, MN
# 3            #470AF5                    3             Pella, IA
# 4            #470AF5                    3         Indianola, IA
# 5            #470AF5                    3           Carroll, IA
# 6            #470AF5                    3           Denison, IA
# 7            #470AF5                    3         Jefferson, IA
# 8            #470AF5                    3             Keene, NH
# 9            #470AF5                    3           Raymond, NH
# 10           #470AF5                    3           Laconia, NH
# 11           #470AF5                    3         Dunbarton, NH
# 12           #470AF5                    3         Goffstown, NH
# 13           #470AF5                    3            Nashua, NH
# 14           #009800                    2  North Charleston, SC
# 15           #009800                    2     West Columbia, SC
# 16           #470AF5                    3         Baltimore, MD
# 17           #009800                    2        Portsmouth, NH
# 18           #009800                    2            Ankeny, IA
# 19           #470AF5                    3          Mayfield, OH
# 20           #009800                    2        Bettendorf, IA
# 21           #009800                    2   North Las Vegas, NV
# 22           #FF2311                    1          New York, NY
# 23           #FF2311                    1           Chicago, IL
# 24           #470AF5                    3        Washington, NJ
# 25           #FF2311                    1            Bluffs, IA
# 26           #FF2311                    1         Iowa City, IA
# 27           #FF2311                    1        Des Moines, IA
# 28           #FF2311                    1           Concord, NH
# 29           #FF2311                    1             Keene, NH
# ..               ...                  ...                   ...
# 104          #009800                    2        Greenville, SC
# 105          #FF2311                    1         Las Vegas, NV
# 106          #FF2311                    1         Pasadena, CA
# 107          #FF2311                    1         San Jose, CA
# 108          #FF2311                    1          Waterloo, IA
# 109          #FF2311                    1    Marchshalltown, IA
# 110          #FF2311                    1       Des Moines, IA
# 111          #009800                    2          Waterloo, IA
# 112          #FF2311                    1           Dubuque, IA
# 113          #009800                    2           Dubuque, IA
# 114          #009800                    2          Columbia, SC
# 115          #470AF5                    3      West Ossipee, NH
# 116          #470AF5                    3             Dover, NH
# 117          #FF2311                    1        Des Moines, IA
# 118          #009800                    2         Las Vegas, NV
# 119          #FF2311                    1            Rapids, IA
# 120          #FF2311                    1           Ottumwa, IA
# 121          #FF2311                    1          Waterloo, IA
# 122          #FF2311                    1            Bluffs, IA
# 123          #FF2311                    1              Ames, IA
# 124          #FF2311                    1         Iowa City, IA
# 125          #FF2311                    1             Keene, NH
# 126          #FF2311                    1           Laconia, NH
# 127          #FF2311                    1        Portsmouth, NH
# 128          #FF2311                    1          Hooksett, NH
# 129          #FF2311                    1            Nashua, NH
# 130          #FF2311                    1           Concord, NH
# 131          #FF2311                    1             Dover, NH
# 132          #FF2311                    1          Columbia, SC
# 133          #FF2311                    1         Rock Hill, SC
#
# [134 rows x 9 columns]

# %% [markdown]
# ### 5.5. Change dataframe to geojason

# %%
# !pip install json
# Out:
# Collecting json
#   Could not find a version that satisfies the requirement json (from versions: )
# No matching distribution found for json
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import json

# %%
ok_json = json.loads(df.to_json(orient='records'))

# %%
def process_to_geojson(file):
    geo_data = {"type": "FeatureCollection", "features":[]}
    for row in file:
        this_dict = {"type": "Feature", "properties":{}, "geometry": {}}
        for key, value in row.items():
            key_names = key.split('.')
            if key_names[0] == 'geometry':
                this_dict['geometry'][key_names[1]] = value
            if str(key_names[0]) == 'properties':
                this_dict['properties'][key_names[1]] = value
        geo_data['features'].append(this_dict)
    return geo_data

# %%
geo_format = process_to_geojson(ok_json)

# %%
with open('geo-data.js', 'w') as outfile:
    outfile.write("var infoData = ")
with open('geo-data.js', 'a') as outfile:
    json.dump(geo_format, outfile)
